# %%
list1 =['a','b','c','d']

list1.append('e')
print(list1)

list1.extend(['ABC','DCE'])

print(list1)

list1.insert(1,"XYZ")
list1.pop()
print(list1)

list1.pop(1)
print(list1)

list1.remove('ABC')
print(list1)

h = set(list1)
print(h)
# Out:
# ['a', 'b', 'c', 'd', 'e']
# ['a', 'b', 'c', 'd', 'e', 'ABC', 'DCE']
# ['a', 'XYZ', 'b', 'c', 'd', 'e', 'ABC']
# ['a', 'b', 'c', 'd', 'e', 'ABC']
# ['a', 'b', 'c', 'd', 'e']
# {'a', 'c', 'e', 'b', 'd'}

# %%
list3 = [1,1,2,2,3,3]
print(list3)

s = set(list3)
print(s)


h = tuple(list3)
print(h)

s2 = set('aabbcccddss')
print(s2)
# Out:
# [1, 1, 2, 2, 3, 3]
# {1, 2, 3}
# (1, 1, 2, 2, 3, 3)
# {'s', 'a', 'c', 'b', 'd'}

# %%
list2 =['apple','ball','cat','dog']
list2.append(5)
list2.append(True)

print(list2)
for i in list1:
    print(type(i))
# Out:
# ['apple', 'ball', 'cat', 'dog', 5, True]
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
s3 ={0,1,'1',True,'True'}
print(s3)
# Out:
# {0, 1, '1', 'True'}

# %%
d1 = { "Name":"Abhijeet",
    "Roll no." : 55,
    "address": "godhani", }
print(type(d1))
print(d1["Roll no."])
# Out:
# <class 'dict'>
# 55

# %%
labA = ['a','b','c']
labB = [1,2,3]

d2 = dict(zip(labA,labB))
print(d2)

for j in d2.keys():
    print(j)

for x,y in d1.items():
    print(x,y)
# Out:
# {'a': 1, 'b': 2, 'c': 3}
# a
# b
# c
# Name Abhijeet
# Roll no. 55
# address godhani
