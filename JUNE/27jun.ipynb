# %%
ln = ["abhijeet","asad","naman","kunal","mukesh"]

for index, name in enumerate(ln, start=1):
    print(index,name)

for i in range(len(ln)):
    print(i,ln[i])
# Out:
# 1 abhijeet
# 2 asad
# 3 naman
# 4 kunal
# 5 mukesh
# 0 abhijeet
# 1 asad
# 2 naman
# 3 kunal
# 4 mukesh

# %%
profile = {
    "name":"abhiijeet",
    "age":20,
    "city":"sakoli",
    "college":"JIT"
}

print(f"mera nam {profile['name']} hai ,meri age {profile['age']}, mai {profile['college']} padata hu" )
# Out:
# mera nam abhiijeet hai ,meri age 20, mai JIT padata hu

# %%
def is_even(a):
    if a%2==0:
        return "number is even"
    else:
        return "Number is odd"

for i in range(1,11):
    print(i,is_even(i))
# Out:
# 1 Number is odd
# 2 number is even
# 3 Number is odd
# 4 number is even
# 5 Number is odd
# 6 number is even
# 7 Number is odd
# 8 number is even
# 9 Number is odd
# 10 number is even

# %%
sen = input("ek sentense likho :")

words = sen.split()
word_count= len(words)
print("totall number of words:",word_count)
print("Upper case",sen.upper())
# Out:
# totall number of words: 0
# Upper case

# %%
# Out:
# {1, 2, 3, 4}
# (1, 2, 3, 4)

# %%
li = [1,2,3,3,4,2,2,4,4]
unique_set = set(li)
print("set",unique_set)
tp = tuple(unique_set)
print("tuple",tp)
# Out:
# set {1, 2, 3, 4}
# tuple (1, 2, 3, 4)

# %%
def save_student(name,age,city):
    student = {
        "name":"abhiijeet",
        "age":20,
        "city":"sakoli",
        "college":"JIT"    
    }

    with open("student.txt","a") as file:
        file.write(f"{student['name']}",{student['city']},{student['age']})
                   
save_student("abhi",20,"sakoli")
save_student("abhijeet",22,"sakoli")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 12
#       9     with open("student.txt","a") as file:
#      10         file.write(f"{student['name']}",{student['city']},{student['age']})
# ---> 12 save_student("abhi",20,"sakoli")
#      13 save_student("abhijeet",22,"sakoli")
#
# Cell In[46], line 10, in save_student(name, age, city)
#       2 student = {
#       3     "name":"abhiijeet",
#       4     "age":20,
#       5     "city":"sakoli",
#       6     "college":"JIT"
#       7 }
#       9 with open("student.txt","a") as file:
# ---> 10     file.write(f"{student['name']}",{student['city']},{student['age']})
#
# TypeError: TextIOWrapper.write() takes exactly one argument (3 given)
