# %%
#apna kam khud ka exmaple bana:
#ek list bana ,usme 5 item daal,loop se print kara
ln = ["abhi ","rose","raka","rani"]
print(type(l))
print(l)

for l in ln:
    print(l)
# Out:
# <class 'int'>
# 4
# abhi
# rose
# raka
# rani

# %%
dic = {
   "name" : "abhijeet",
    "age":20,
    "city":"nagpur"


}
print(dic)
# Out:
# {'name': 'abhijeet', 'age': 20, 'city': 'nagpur'}

# %%
for i in range(10):
    if i%2==0:
        print(i)
print("-------")
i = 1
while i<=5:
    print(i)
    i+=1
# Out:
# 0
# 2
# 4
# 6
# 8
# -------
# 1
# 2
# 3
# 4
# 5

# %%
def mul(a,b):
    return a*b

a1 = float(input("enter"))
b2= float(input("enter"))


result = mul(a1,b2)
print(result)
