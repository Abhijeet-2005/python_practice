# %%
import pandas as pd

data1 = {
    "Product":["laotop","phone","dslr"],
    "price":[70000,17000,35900]

}

df = pd.DataFrame(data1)
print(df[df["price"] > 16900])
# Out:
#   Product  price
# 0  laotop  70000
# 1   phone  17000
# 2    dslr  35900

# %%
class library:
    def __init__(self,book_n,author):
        self.book_n = book_n
        self.author = author 

    def show(self):
        print(f"book:{self.book_n}, author:{self.author}")

b = library("godhan","munshi prem chand")
b.show()
# Out:
# book:godhan, author:munshi prem chand

# %%
import numpy as np
prices = np.array([70000,17000,35900])
print("average price:",prices.mean())
# Out:
# average price: 40966.666666666664
