# %%
# import numpy as np
# print("Numpy ready!")
# Out:
# Numpy ready!

# %%
import numpy as np
arr = np.array([10,20,30,40,50])
print(arr.sum())
print(arr.mean())
print(arr.max())
print(arr.min())
# Out:
# 150
# 30.0
# 50
# 10

# %%
import numpy  as np
arr = np.array([1,3,4,4])
print(arr)
print(type(arr))
# Out:
# [1 3 4 4]
# <class 'numpy.ndarray'>
