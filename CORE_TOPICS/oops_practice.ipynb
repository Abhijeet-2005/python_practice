# %%
class book:
    def __init__(self,title,author,price):
        self.title= title
        self.author= author
        self.price= price

    def show(self):
        print(f"title: {self.title}, Author: {self.author},price: {self.price}")
        
class ebook(book):
    def __init__(self, title, author, price,file_s):
        super().__init__(title, author, price)
        self.file_s = file_s

    def show(self):
        super().show()
        print(f"file size:{self.file_s} MB")

class printedbook(book):
    def __init__(self, title, author, price,pages):
        super().__init__(title, author, price)
        self.pages = pages

    def show(self):
        super().show()
        print(f"pages : {self.pages}")

e1 = ebook("python basics","harry",500,3)
p1= printedbook("DSA book","striver",300,450)
e1.show()
p1.show()
# Out:
# title: python basics, Author: harry,price: 500
# file size:3 MB
# title: DSA book, Author: striver,price: 300
# pages : 450
