# %%
# Using python _os_ module it is possible to automatically perform many operating system tasks. 
# The OS module in Python provides functions for creating, changing current working directory, 
# and removing a directory (folder), fetching its contents, changing and identifying the current directory.
import os
os.mkdir("example")
print(os.getcwd())
# Out:
# c:\Users\abhij\Desktop\Python_Basics\CORE_TOPICS

# %%
import sys

if len(sys.argv) < 3:
    print("Usage: python script.py abhijeet <challenge>")
else:
    print('Welcome {}. Enjoy {} challenge!'.format(sys.argv[1], sys.argv[2]))

print("Max integer size:", sys.maxsize)
print("Environment paths:", sys.path)
print("Python version:", sys.version)


# To know the largest integer variable it takes
sys.maxsize

#to know the environment path
sys.path

#to know the verion path
sys.version
# Out:
# Usage: python script.py abhijeet <challenge>
# Max integer size: 9223372036854775807
# Environment paths: ['c:\\Users\\abhij\\anaconda3\\python313.zip', 'c:\\Users\\abhij\\anaconda3\\DLLs', 'c:\\Users\\abhij\\anaconda3\\Lib', 'c:\\Users\\abhij\\anaconda3', '', 'c:\\Users\\abhij\\anaconda3\\Lib\\site-packages', 'c:\\Users\\abhij\\anaconda3\\Lib\\site-packages\\win32', 'c:\\Users\\abhij\\anaconda3\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\abhij\\anaconda3\\Lib\\site-packages\\Pythonwin']
# Python version: 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]'

# %%
# Statistics Module
from statistics import *
ages = [20, 20,  24, 25, 22, 26, 20, 23, 22, 26]
print(mean(ages))#Mean → The average value.
print(median(ages))#median the middle value
print(mode(ages)) #most freqaunt value in list
print(stdev(ages))#A measure of how spread out the data is around the mean(ek lsit aur dursi ke bich ka kitne number ka gap hai)
# Out:
# 22.8
# 22.5
# 20
# 2.3944379994757297

# %%
###math module 
from math import pi 

print(pi)

from math import pi,pow,sqrt,floor,ceil,log10
#instead of this pi,pow,sqrt,floor,ceil,log10 we can use this * to import all 
print(pi)
print(pow(2,3))
print(sqrt(4))
print(floor(9.3455))# Rounds a number down to the nearest integer.
print(ceil(9.4848))#Rounds a number up to the nearest intege
print(log10(10))

# %%
##string module 
import string
print(string.ascii_letters)
print(string.ascii_lowercase)
print(string.ascii_uppercase)

print(string.digits)
print(string.punctuation)

from random import random ,randint
print(random())
print(randint(5,20))
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
# abcdefghijklmnopqrstuvwxyz
# ABCDEFGHIJKLMNOPQRSTUVWXYZ
# 0123456789
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# 0.8788665592679682
# 12

# %%
### Exercises: Level 1
import random
import string 

def random_user_id():
    character = string.ascii_lowercase + string.digits
    user_id = ''.join(random.choice(character) for _ in range(6))
    return user_id
print(random_user_id())
print(random_user_id())
print(random_user_id())
# Out:
# aqcl2w
# 0xhy29
# l7nm62

# %%
# 2. Modify the previous task. Declare a function named user_id_gen_by_user.
# It doesn’t take any parameters but it takes two inputs using input().
# One of the inputs is the number of characters and the second input is the number of IDs which are supposed to be generated.
   
import random
import string 

def user_id_gen_by_user():
    numchar = int(input("enter the number:"))
    numid = int(input("enter the number"))

    character = string.ascii_lowercase + string.digits

    for _ in range(numid):
        user_id = ''.join(random.choice(character) for _ in range(numchar))
        print(user_id)
user_id_gen_by_user()
# Out:
# jp9pri5e
# dtgm7ph4
# qrpnosww
# a0czz2d3
# 9r7oek5n
# bqtsc0wi

# %%
# 3. Write a function named rgb_color_gen. It will generate rgb colors (3 values ranging from 0 to 255 each).
import string
import random 

def rgb():
    n1 = string.digits

    color1 = random.randint(0,255) 
    color2 = random.randint(0,255) 
    color3 = random.randint(0,255) 

    return color1,color2,color3
rgb()
# Out:
# (140, 173, 96)

# %%
### Exercises: Level 2
# Write a function list_of_hexa_colors which returns any number of hexadecimal colors in an array (six hexadecimal numbers written after 
# #. Hexadecimal numeral system is made out of 16 symbols, 0-9 and first 6 letters of the alphabet, a-f. Check the task 6 for output examples).
import random

pool = '0123456789abcdef'
def list_hexa_color(num_colors):
    colors = []
    for _ in range(num_colors):
        hex_color = '#'+''.join(random.choice(pool) for _ in range(6))
        colors.append(hex_color)
    return colors
list_hexa_color(3)
# Out:
# ['#5ae2db', '#1d6022', '#5b216f']

# %%
#1. Write a function list_of_rgb_colors which returns any number of RGB colors in an array.
import random
import string

def list_rgb_colors(num_colors):
    colors= []
    numbers = string.digits
    for _ in range(num_colors):
        col =(random.randint(0,255),
              random.randint(0,255),
              random.randint(0,255))
        colors.append(col)
    return colors
list_rgb_colors(3)
# Out:
# [(68, 71, 41), (197, 52, 96), (14, 157, 24)]

# %%
n = input("enter")
if n == 'rgb':
    print(list_rgb_colors(3))
elif n == 'hexa':
    print(list_hexa_color(2))
else:
    print("invalid")
# Out:
# ['#af0fb0', '#6a64d1']

# %%
import random

list1 =[]
for i in range(6):
    number = random.randint(0,100)
    list1.append(number)

print(list1)
# Out:
# [10, 96, 95, 100, 42, 24]

# %%
# ## Exercises: Level 3

# 1. Call your function shuffle_list, it takes a list as a parameter and it returns a shuffled list
import random

def shuffle_list(l):
    random.shuffle(l)
    return l
number = [1,2,3,4,5]
print(shuffle_list(number))

# 1. Write a function which returns an array of seven random numbers in a range of 0-9. All the numbers must be unique.

def unique():
    return random.sample(range(10),7)

print(unique())

# 🎉 CONGRATULATIONS ! 🎉
# Out:
# [5, 2, 4, 3, 1]
# [5, 6, 9, 4, 2, 7, 1]
