# %%
text = "abhi jeet"
print(text.upper())
print(text.lower())
print(text.split())
print(text.replace("abhijeet","hello"))
print(len(text))
print(text.strip())
# Out:
# ABHI JEET
# abhi jeet
# ['abhi', 'jeet']
# abhi jeet
# 9
# abhi jeet

# %%
text1= "hello world we are ready"
print(text1.upper())
# Out:
# HELLO WORLD WE ARE READY

# %%
text2= "hello world we are ready"
h = text2.split()
print(len(h))
print(h)
# Out:
# 5
# ['hello', 'world', 'we', 'are', 'ready']

# %%
sen = "i love python "
print(sen)
print(sen.replace("python","coding "))
# Out:
# i love python
# i love coding

# %%
name = input("apana nam likhye ")
print(f"Hello",{name.upper()})
