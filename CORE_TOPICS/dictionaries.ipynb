# %%
# - [Dictionaries](#dictionaries)

#     - [Creating a Dictionary](#creating-a-dictionary)
person = {
    'first_name':'Abhijeet',
    'last_name':'zingare',
    'age':20,
    'country':'india',
    'is_marred':False,
    'skills':['communication', 'ml', 'dsa', 'ai', 'Python'],
  
    }
#     - [Dictionary Length](#dictionary-length)
print("lenght of dictionary:",len(person))
#     - [Accessing Dictionary Items](#accessing-dictionary-items)
print(person['first_name'])
print(person['age'])
#     - [Adding Items to a Dictionary](#adding-items-to-a-dictionary)
person['occupation']= 'student'
person['skills'].append('problem solving')
print(person)
#     - [Modifying Items in a Dictionary](#modifying-items-in-a-dictionary)
person['age']= 25
print(person)


#     - [Checking Keys in a Dictionary](#checking-keys-in-a-dictionary)
print('first_name' in person)
print('last_name' in person)
#     - [Removing Key and Value Pairs from a Dictionary](#removing-key-and-value-pairs-from-a-dictionary)
person.pop('is_marred')
person.popitem()

del person['country']
print(person)

#     - [Changing Dictionary to a List of Items](#changing-dictionary-to-a-list-of-items)
print(person.items()) # IT CREATE DICT TO T LIST OF TUPLE , _items()_ method changes dictionary to a list of tuples.

#     - [Copy a Dictionary](#copy-a-dictionary)
dct2 = person.copy()
print("copying dictionary:",dct2)
#     - [Getting Dictionary Keys as a List](#getting-dictionary-keys-as-a-list)
person_key = person.keys()
print(person_key)
#     - [Getting Dictionary Values as a List](#getting-dictionary-values-as-a-list)
person_value = person.values()
print(person_value)
#     - [Clearing a Dictionary](#clearing-a-dictionary)
person.clear()
print(person)
#     - [Deleting a Dictionary](#deleting-a-dictionary)
del person
# Out:
# lenght of dictionary: 6
# Abhijeet
# 20
# {'first_name': 'Abhijeet', 'last_name': 'zingare', 'age': 20, 'country': 'india', 'is_marred': False, 'skills': ['communication', 'ml', 'dsa', 'ai', 'Python', 'problem solving'], 'occupation': 'student'}
# {'first_name': 'Abhijeet', 'last_name': 'zingare', 'age': 25, 'country': 'india', 'is_marred': False, 'skills': ['communication', 'ml', 'dsa', 'ai', 'Python', 'problem solving'], 'occupation': 'student'}
# True
# True
# {'first_name': 'Abhijeet', 'last_name': 'zingare', 'age': 25, 'skills': ['communication', 'ml', 'dsa', 'ai', 'Python', 'problem solving']}
# dict_items([('first_name', 'Abhijeet'), ('last_name', 'zingare'), ('age', 25), ('skills', ['communication', 'ml', 'dsa', 'ai', 'Python', 'problem solving'])])
# copying dictionary: {'first_name': 'Abhijeet', 'last_name': 'zingare', 'age': 25, 'skills': ['communication', 'ml', 'dsa', 'ai', 'Python', 'problem solving']}
# dict_keys(['first_name', 'last_name', 'age', 'skills'])
# dict_values(['Abhijeet', 'zingare', 25, ['communication', 'ml', 'dsa', 'ai', 'Python', 'problem solving']])
# {}

# %%
# #   - [💻 Exercises: Day 8](#-exercises-day-8)
# 1. Create  an empty dictionary called dog
dog ={}
# 2. Add name, color, breed, legs, age to the dog dictionary
dog['name']= 'danny'
dog['color']='white'
dog['breed']='labra'
dog['leg']=4
# 3. Create a student dictionary and add first_name, last_name, gender, age, marital status, skills, country, city and address as keys for the dictionary
student = {
    'name':'abhijeet',
    'last':'zingare',
    'gender':'male',
    'age':20,
    'marital':False,
    'skills':['problem solving','communiction','ml','ptyhon'],
    'country':'india',
    'city':'nagpur',
    'adress':'godhani,nagpur'

}
# 4. Get the length of the student dictionary
print("lenght of student dictionary :",len(student))

# 5. Get the value of skills and check the data type, it should be a list
print(student.get('skills'),type(student['skills']))
# 6. Modify the skills values by adding one or two skills
student['skills'].append('ai')
# 7. Get the dictionary keys as a list
student_keys = student.keys()
print(student_keys)
# 8. Get the dictionary values as a list
student_values = student.values()
print(student_values)
# 9. Change the dictionary to a list of tuples using _items()_ method
print(student.items())
# 10. Delete one of the items in the dictionary
del student['adress']

# 11. Delete one of the dictionaries
del student
# Out:
# lenght of student dictionary : 9
# ['problem solving', 'communiction', 'ml', 'ptyhon'] <class 'list'>
# dict_keys(['name', 'last', 'gender', 'age', 'marital', 'skills', 'country', 'city', 'adress'])
# dict_values(['abhijeet', 'zingare', 'male', 20, False, ['problem solving', 'communiction', 'ml', 'ptyhon', 'ai'], 'india', 'nagpur', 'godhani,nagpur'])
# dict_items([('name', 'abhijeet'), ('last', 'zingare'), ('gender', 'male'), ('age', 20), ('marital', False), ('skills', ['problem solving', 'communiction', 'ml', 'ptyhon', 'ai']), ('country', 'india'), ('city', 'nagpur'), ('adress', 'godhani,nagpur')])
