# %%
# 1. Maximum of Three Numbers

def maximum(a,b,c):
    print("MAXIMUM OF THREE NUMBER is  ",max(a,b,c))

a = input("enter the number 1:")
b = input("enter the number 2:")
c = input("enter the number 3:")

maximum(a,b,c)
# Out:
# MAXIMUM OF THREE NUMBER is   4

# %%
# 2. Sum All Numbers in a List

# Write a Python function to sum all the numbers in a list.

# Sample List : (8, 2, 3, 0, 7)
# Expected Output : 20
def sum(number):
    total =0
    for i in number:
        total += i

    return total
print(sum((1,2,3,3,4,8,9,8)))
# Out:
# 38

# %%
# 3. Multiply All Numbers in a List

# Write a Python function to multiply all the numbers in a list.

# Sample List : (8, 2, 3, -1, 7)
# Expected Output : -336

def mul(number):
    total =1 
    for i in number:
        total *= i
     
    return total
print(mul((2,3,4,5,6)))
# Out:
# 720

# %%
# 4. Reverse a String

# Write a Python program to reverse a string.

# Sample String : "1234abcd"
# Expected Output : "dcba4321"

def text(a):
    #method one slice
    # reverse_string = a[::-1]

    #method two : using reversed and jion
    # reverse_string = "".join(reversed(a))


    # Method 3: Using a For Loop
    reverse_string = ""
    for char in a:
        reverse_string = char+ reverse_string

    print(reverse_string)

    
b = str(input("enter the line :"))

text(b)
# Out:
# olleh

# %%
def arbitrary_named_args(**args):
    print("I received an arbitrary number of arguments, totaling", len(args))
    print("They are provided as a dictionary in my function:", type(args))
    print("Let's print them:")
    for k, v in args.items():
        print(" * key:", k, "value:", v)

# %%
# ## Exercises: Level 1

# 1. Declare a function _add_two_numbers_. It takes two parameters and it returns a sum.
def addtwonumber(n1,n2):
    return n1+n2
addtwonumber(3,4)
# 2. Area of a circle is calculated as follows: area = π x r x r. Write a function that calculates _area_of_circle_.
def areac(r):
    area = 3.14*r*r
    return area
areac(4)

# 3. Write a function called add_all_nums which takes arbitrary number of arguments and sums all the arguments. Check if all the list items are number types. If not do give a reasonable feedback.
def add_all_nums(*arbit):
    sum=0
    for num in arbit:
        sum += num
    return sum
print(add_all_nums(2,4,4))
# 4. Temperature in °C can be converted to °F using this formula: °F = (°C x 9/5) + 32. Write a function which converts °C to °F, _convert_celsius_to-fahrenheit_.
def convert(c):
    f = ( c *9/5) + 32
    return f
print("celecius 4 degree convert into ",convert(4))
# 5. Write a function called check-season, it takes a month parameter and returns the season: Autumn, Winter, Spring or Summer.
def check_season(month):
    month = month.lower()
    if month in ["september","october","november"]:
        print("autumn")
    elif month in ["december","january","february"]:
        print("winter")
    elif month in ["march","april","may"]:
        print("spring")
    elif month in ["june","july","august"]:
        print("summer")
    else:
        print("invalid")
check_season("march")
# Out:
# 10
# celecius 4 degree convert into  39.2
# spring

# %%
# 6. Write a function called calculate_slope which return the slope of a linear equation
def calculate_slope(x1,x2,y1,y2):
    if x1==x2:
        return "undefine slope(verical line)"
    else :
        return (y2-y1)/(x2-x1)
calculate_slope(2,3,4,3)
# 7. Quadratic equation is calculated as follows: ax² + bx + c = 0. Write a function which calculates solution set of a quadratic equation, _solve_quadratic_eqn_.
import math
def qaudraticeq(a,b,c):
    d = b**2 - 4*a*c
    if a==0:
        return "not quadratic equation(a cannot be 0) "
    
    elif d >0:
        root1 = -b+ math.sqrt(d)/2*a
        root2 = -b-math.sqrt(d)/2*a
        return (root1,root2)
    elif d == 0:
        root= -b/2*a
    else:
         real_part = -b / (2*a)
         imaginary_part = math.sqrt(-d) / (2*a)
         return (complex(real_part, imaginary_part), complex(real_part, -imaginary_part))
print(qaudraticeq(1,2,3,))
# 8. Declare a function named print_list. It takes a list as a parameter and it prints out each element of the list.
def print_list(lis):
    for i in range(len(lis)):
        print(lis[i])
    
l = (2,3,4,5,6,7,7,5)
print(print_list(l))
# 9. Declare a function named reverse_list. It takes an array as a parameter and it returns the reverse of the array (use loops).
def reverse_list(array):
    n =len(array)
    reversed_array= []

    for i in range(n-1,-1,-1):
        reversed_array.append(array[i])
    return reversed_array
array1 = [1,2,3,4,5,6]
print(reverse_list(array1))

# ```py
# print(reverse_list([1, 2, 3, 4, 5]))
# # [5, 4, 3, 2, 1]
# print(reverse_list(["A", "B", "C"])) 
# # ["C", "B", "A"]
# ```

# 10. Declare a function named capitalize_list_items. It takes a list as a parameter and it returns a capitalized list of items
def capitalize_list_items(l):
    for i in range(len(l)):
        l[i]=l[i].upper()
    return l
li = ["abhijeet","a","b","n"]

print(capitalize_list_items(li))
# 11. Declare a function named add_item. It takes a list and an item parameters. It returns a list with the item added at the end.
def add_item(l,item):
    l.append(item)
    return l
food_stuff = ['Potato', 'Tomato', 'Mango', 'Milk']

print(add_item(food_stuff,'Meat'))
# ```py
# ;
# print(add_item(food_stuff, 'Meat'))     # ['Potato', 'Tomato', 'Mango', 'Milk','Meat'];
numbers = [2, 3, 7, 9]
print(add_item(numbers, 5))      # 

# ```

# 12. Declare a function named remove_item. It takes a list and an item parameters. It returns a list with the item removed from it.
def remove_item(l,item):
    if item in l:
         l.remove(item)
    return l

# ```py
food_stuf = ['Potato', 'Tomato', 'Mango', 'Milk']
print(remove_item(food_stuf, 'Mango'))  # ['Potato', 'Tomato', 'Milk'];
number = [2, 3, 7, 9]
print(remove_item(number, 3))  # [2, 7, 9]
# ```

# 13. Declare a function named sum_of_numbers. It takes a number parameter and it adds all the numbers in that range.
def sum_of_number(num):
    total = 0
    for i in range(num+1):
        total+=i

    return total
print()
# ```py
print(sum_of_number(5))  # 15
print(sum_of_number(10)) # 55
print(sum_of_number(100)) # 5050
# ```

# 14. Declare a function named sum_of_odds. It takes a number parameter and it adds all the odd numbers in that range.
def sum_of_odds(numb):
    total= 0
    for i in range(numb+1):
         if i%2!=0:
             total +=i
    return total 
print(sum_of_odds(9))
print(sum_of_odds(45))
print(sum_of_odds(50))

# 15. Declare a function named sum_of_even. It takes a number parameter and it adds all the even numbers in that - range.
def sum_of_even(numb):
    total=0
    for i in range(0,numb+1,1):
        total+=i
    return total
print(sum_of_even(5))
print(sum_of_even(30))

print(sum_of_even(79))
#
# Out:
# ((-1+1.4142135623730951j), (-1-1.4142135623730951j))
# 2
# 3
# 4
# 5
# 6
# 7
# 7
# 5
# None
# [6, 5, 4, 3, 2, 1]
# ['ABHIJEET', 'A', 'B', 'N']
# ['Potato', 'Tomato', 'Mango', 'Milk', 'Meat']
# [2, 3, 7, 9, 5]
# ['Potato', 'Tomato', 'Milk']
# [2, 7, 9]
#
# 15
# 55
# 5050
# 25
# 529
# 625
# 15
# 465
# 3160

# %%
### Exercises: Level 2

# 1. Declare a function named evens_and_odds . It takes a positive integer as parameter and it counts number of evens and odds in the number.
def evens_and_odds(a):
    odd=0
    even=0

    for i in range(a+1):
        if i%2==0:
            even+=1
        else:
            odd+=1
    return "odd",odd,"even",even

print(evens_and_odds(100))
    # The number of odds are 50.
    # The number of evens are 51.

# 1. Call your function factorial, it takes a whole number as a parameter and it return a factorial of the number
def factorial(a):
   if a == 0:
       return 1
   result= a*factorial(a-1)
   return result
print(factorial(3))
print(factorial(5))
print(factorial(10))

# 1. Call your function _is_empty_, it takes a parameter and it checks if it is empty or not
def _is_empty_(a):
    if a is None:
        return True
    if isinstance(a,(list,tuple,dict,str,set)):
        return len(a) == 0
    return False
print("check:",_is_empty_("abhijeet"))
print("check:",_is_empty_(""))

# 1. Write different functions which take lists. They should calculate_mean, calculate_median, calculate_mode, calculate_range, calculate_variance, calculate_std (standard deviation).
def calculate(l):
    total = 0
    #mean
    for i in range(len(l)):
        total+=l[i]
    
    n = len(l)

    mean = total/n
    #midian
    l_sorted = sorted(l)
    middle= n//2
    if n%2==0:
        median= (l_sorted[middle-1:middle+1])
    else:
        median =(l_sorted[middle])

    #mode
    freq = {}
    for item in l:
        freq[item] = freq.get(item, 0) + 1
    maxcount = max(freq.values())
    mode = [key for key, count in freq.items() if count == maxcount]
    if maxcount == 1:
        mode = None
    #range
    value_range= max(l)-min(l)
    #vairanace
    variance = sum((x - mean) ** 2 for x in l) / n
    return {
        "mean": mean,
        "median": middle,
        "mode": mode,
        "range":value_range,
        "vairance":variance
            }
    
l1 = [1,2,3,4,5,3,4,4,4]
print(calculate(l1))
# 1. Write a function called _greet_ which takes a default argument, _name_. If no argument is supplied it should print "Hello, Guest!", otherwise it should greet the person by name.
def greet(name= "guest"):
        print("hello",name)
   
# ```py
greet()
#     # "Hello, Guest!
greet("Alice")
#     # "Hello, Alice!"
# ```
# 1. Create a function called _show_args_ to take an arbitrary number of named arguments and print their names and values.
def show_args(**kwargs):
    for key,values in kwargs.items():
        print(f"{key}:{values}")
#    ```py
show_args(name="Alice", age=30, city="New York")
#    # Received: name: Alice, age: 30, city: New York
show_args(name="Bob", pet="Fluffy, the bunny")
#    # Received: name: Bob, pet: Fluffy, the bunny
#    ```
# Out:
# ('odd', 50, 'even', 51)
# 6
# 120
# 3628800
# check: False
# check: True
# {'mean': 3.3333333333333335, 'median': 4, 'mode': [4], 'range': 4, 'vairance': 1.3333333333333333}
# hello guest
# hello Alice
# name:Alice
# age:30
# city:New York
# name:Bob
# pet:Fluffy, the bunny

# %%
# ### Exercises: Level 3

# 1. Write a function called is_prime, which checks if a number is prime.
import math
def is_prime(n):
    if n<0:
        return False
    if n==0:
        return True

    for i in range(3,int(math.sqrt(n)+1),2):
        if n%i==0:
            return False
    return True
num = 29
if is_prime(num):
    print(f"{num} is a prime number.")
else:
    print(f"{num} is not a prime number.")

# 1. Write a functions which checks if all items are unique in the list.
def unique(l):
    j=1
    for i in range(len(l)):
        for j in range(i):
            if l[i]==l[j]:
                return "list have duplicate values"
            else: 
                pass
    return "list have unique values"
l = [11,33,4,22,22,44,11,]
l1 = [1,34,5,6]
print(unique(l))
print(unique(l1))

# 1. Write a function which checks if all the items of the list are of the same data type.
def check_Dtype(li):
    if not li :
        return "lsit is empty"
    for i in range(len(li)):
            if type(li[i])!=type(li[0]):
                return "not same data type"
    return "they are same data type"
l2 = [1,"hello ",34,5,6]

print(check_Dtype(l))
print(check_Dtype(l2))

# 1. Write a function which check if provided variable is a valid python variable
def check(a):
    if type(a) is int:
        return "valid"
    elif type(a) is float:
        return "valid"
    elif type(a) is str:
        return "valid"
    else:
        return "not valid"
print(check("hello"))
print(check(34))
print(check(3.4))
print(check(True))

# 1. Go to the data folder and access the countries-data.py file.

# - Create a function called the most_spoken_languages in the world. It should return 10 or 20 most spoken languages in the world in descending order
# - Create a function called the most_populated_countries. It should return 10 or 20 most populated countries in descending order.
# Out:
# 29 is a prime number.
# list have duplicate values
# list have unique values
# they are same data type
# not same data type
# valid
# valid
# valid
# not valid
