# %%
# task 3
print("________________________")
#specific column 
print(df["name"])

age_20 =df[df["Age"] == 20]
print(age_20)
print("----------------------------")


high_scores = df[df["Mark"]>85]
print(high_scores)
print("----------------------------")


sorted_df = df.sort_values("Mark",ascending=False)
print(sorted_df)
print("----------------------------")


sorted_f = high_scores.sort_values("Mark",ascending=False)
print(sorted_f)
# Out:
# ________________________
# 0       abhi
# 1      vipul
# 2    utkarsh
# 3      rohan
# Name: name, dtype: object
#     name  Age  Mark
# 0   abhi   20    85
# 3  rohan   20    89
# ----------------------------
#     name  Age  Mark
# 1  vipul   21    93
# 3  rohan   20    89
# ----------------------------
#       name  Age  Mark
# 1    vipul   21    93
# 3    rohan   20    89
# 0     abhi   20    85
# 2  utkarsh   19    34
# ----------------------------
#     name  Age  Mark
# 1  vipul   21    93
# 3  rohan   20    89

# %%
import pandas as pd 
data = {
    "name":["abhi","vipul","utkarsh"],
    "Age":[20,21,19],
    "City":["delhi","mumbai","pune"]

}
 
df = pd.DataFrame(data)
print(df)
print("______________-")

print(df.head())#phehli 5 rows 
print(df.shape)#(rows,column)
print(df.columns)#column names

high = df[df["Age"]>20]
print(high)
# Out:
#       name  Age    City
# 0     abhi   20   delhi
# 1    vipul   21  mumbai
# 2  utkarsh   19    pune
# ______________-
#       name  Age    City
# 0     abhi   20   delhi
# 1    vipul   21  mumbai
# 2  utkarsh   19    pune
# (3, 3)
# Index(['name', 'Age', 'City'], dtype='object')
#     name  Age    City
# 1  vipul   21  mumbai

# %%
# task 1: MAKING DATA FRAME 
import pandas as pd 
data1 = {
    "name":["abhi","vipul","utkarsh","rohan"],
    "Age":[20,21,19,20],
    "Mark":[85,93,34,89]

}
df = pd.DataFrame(data1)
print(df)

#task 2 :Basic info 
print(df.shape)
print(df.columns)
# Out:
#       name  Age  Mark
# 0     abhi   20    85
# 1    vipul   21    93
# 2  utkarsh   19    34
# 3    rohan   20    89
# (4, 3)
# Index(['name', 'Age', 'Mark'], dtype='object')
